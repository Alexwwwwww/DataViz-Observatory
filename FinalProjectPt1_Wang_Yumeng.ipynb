# %%
# !pip install bqplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bqplot in /usr/local/lib/python3.8/dist-packages (0.12.36)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from bqplot) (1.3.5)
# Requirement already satisfied: numpy<2.0.0,>=1.10.4 in /usr/local/lib/python3.8/dist-packages (from bqplot) (1.21.6)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.8/dist-packages (from bqplot) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from bqplot) (5.6.0)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in /usr/local/lib/python3.8/dist-packages (from bqplot) (7.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<9,>=7.5.0->bqplot) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<9,>=7.5.0->bqplot) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<9,>=7.5.0->bqplot) (7.9.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<9,>=7.5.0->bqplot) (3.0.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets<9,>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.5.0->bqplot) (6.1.12)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (57.4.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (0.18.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (2.0.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.0.0->bqplot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.0.0->bqplot) (2022.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7.5.0->bqplot) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.7.16)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.1.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.13.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (23.2.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.15.0)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (2.11.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.7.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.6.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (2.5.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (3.11.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.5.0->bqplot) (0.5.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlp
import plotly.express as px
import bqplot
# %matplotlib inline

# %% [markdown]
# ### **Inspect the columns**
# Read CSV files from the original dataset: https://github.com/washingtonpost/data-2C-beyond-the-limit-usa

# %%
# extract data
national_data = pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-2C-beyond-the-limit-usa/main/data/processed/climdiv_national_year.csv', dtype={"fips": str})
state_data = pd.merge(pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-2C-beyond-the-limit-usa/main/data/processed/climdiv_state_year.csv', dtype={"fips": str}), pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-2C-beyond-the-limit-usa/main/data/processed/model_state.csv', dtype={"fips": str}), on ='fips')
county_data = pd.merge(pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-2C-beyond-the-limit-usa/main/data/processed/climdiv_county_year.csv', dtype={"fips": str}), pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-2C-beyond-the-limit-usa/main/data/processed/model_county.csv', encoding = "latin-1", dtype={"fips": str}), on ='fips')

# %%
national_data.head()
# Out:
#    year       temp      tempc
# 0  1895  50.337500  10.187500
# 1  1896  51.993333  11.107407
# 2  1897  51.556667  10.864815
# 3  1898  51.431667  10.795370
# 4  1899  51.009167  10.560648

# %%
state_data.head()
# Out:
#   fips  year       temp      tempc      Fall    Spring    Summer    Winter  \
# 0   01  1895  61.641667  16.467593 -0.195668 -0.105862 -0.325009  0.458526
# 1   01  1896  64.266667  17.925926 -0.195668 -0.105862 -0.325009  0.458526
# 2   01  1897  64.191667  17.884259 -0.195668 -0.105862 -0.325009  0.458526
# 3   01  1898  62.983333  17.212963 -0.195668 -0.105862 -0.325009  0.458526
# 4   01  1899  63.100000  17.277778 -0.195668 -0.105862 -0.325009  0.458526
#
#   max_warming_season    Annual STUSAB STATE_NAME  STATENS
# 0             Winter -0.035048     AL    Alabama  1779775
# 1             Winter -0.035048     AL    Alabama  1779775
# 2             Winter -0.035048     AL    Alabama  1779775
# 3             Winter -0.035048     AL    Alabama  1779775
# 4             Winter -0.035048     AL    Alabama  1779775

# %%
county_data.describe()
# Out:
#                 year           temp          tempc           Fall  \
# count  388375.000000  388375.000000  388375.000000  388375.000000
# mean     1957.000000      53.995737      12.219854       0.541821
# std        36.083284       8.431610       4.684228       0.535830
# min      1895.000000      30.508333      -0.828704      -0.845813
# 25%      1926.000000      47.650000       8.694444       0.152437
# 50%      1957.000000      53.908333      12.171296       0.497030
# 75%      1988.000000      60.533333      15.851852       0.899584
# max      2019.000000      78.816667      26.009259       2.526660
#
#               Spring         Summer         Winter         Annual
# count  388375.000000  388375.000000  388375.000000  388375.000000
# mean        0.827684       0.455960       1.414876       0.814849
# std         0.535507       0.617663       0.713179       0.547218
# min        -0.609171      -0.943591      -0.197573      -0.566222
# 25%         0.434949      -0.007224       0.951139       0.400667
# 50%         0.831619       0.344198       1.322314       0.743877
# 75%         1.213813       0.871605       1.804106       1.204825
# max         2.786215       2.583295       3.736705       2.537160

# %% [markdown]
# ### **Filter the data to the state of interest (Illinois)**

# %%
state_data_illinois = state_data[state_data['STATE_NAME'] == 'Illinois']
state_data_illinois
# Out:
#      fips  year       temp      tempc      Fall    Spring    Summer    Winter  \
# 1250   17  1895  49.716667   9.842593  0.557305  1.153298  0.217481  1.308741
# 1251   17  1896  52.200000  11.222222  0.557305  1.153298  0.217481  1.308741
# 1252   17  1897  51.400000  10.777778  0.557305  1.153298  0.217481  1.308741
# 1253   17  1898  51.300000  10.722222  0.557305  1.153298  0.217481  1.308741
# 1254   17  1899  50.816667  10.453704  0.557305  1.153298  0.217481  1.308741
# ...   ...   ...        ...        ...       ...       ...       ...       ...
# 1370   17  2015  52.875000  11.597222  0.557305  1.153298  0.217481  1.308741
# 1371   17  2016  54.733333  12.629630  0.557305  1.153298  0.217481  1.308741
# 1372   17  2017  54.391667  12.439815  0.557305  1.153298  0.217481  1.308741
# 1373   17  2018  52.475000  11.375000  0.557305  1.153298  0.217481  1.308741
# 1374   17  2019  52.091667  11.162037  0.557305  1.153298  0.217481  1.308741
#
#      max_warming_season   Annual STUSAB STATE_NAME  STATENS
# 1250             Winter  0.81442     IL   Illinois  1779784
# 1251             Winter  0.81442     IL   Illinois  1779784
# 1252             Winter  0.81442     IL   Illinois  1779784
# 1253             Winter  0.81442     IL   Illinois  1779784
# 1254             Winter  0.81442     IL   Illinois  1779784
# ...                 ...      ...    ...        ...      ...
# 1370             Winter  0.81442     IL   Illinois  1779784
# 1371             Winter  0.81442     IL   Illinois  1779784
# 1372             Winter  0.81442     IL   Illinois  1779784
# 1373             Winter  0.81442     IL   Illinois  1779784
# 1374             Winter  0.81442     IL   Illinois  1779784
#
# [125 rows x 13 columns]

# %% [markdown]
# #### **Simple visulization to get a big picture of data**
# explore the temperature of illinois

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
# reference: lecture_13_timeseries_and_map_continued
x_sc = bqplot.DateScale()
y_sc = bqplot.LinearScale()

# Axis
x_ax = bqplot.Axis(scale=x_sc, label='Year')
y_ax1 = bqplot.Axis(scale=y_sc, label='Spring', orientation='vertical')
y_ax2 = bqplot.Axis(scale=y_sc, label='Summer', orientation='vertical')
y_ax3 = bqplot.Axis(scale=y_sc, label='Fall', orientation='vertical')
y_ax4 = bqplot.Axis(scale=y_sc, label='Winter', orientation='vertical')

lines = bqplot.Lines(x=state_data_illinois["year"], 
                     y=state_data_illinois["Spring"], 
                     scales={'x':x_sc, 'y':y_sc})
lines = bqplot.Lines(x=state_data_illinois["year"], 
                     y=state_data_illinois["Summer"], 
                     scales={'x':x_sc, 'y':y_sc})
lines = bqplot.Lines(x=state_data_illinois["year"], 
                     y=state_data_illinois["Fall"], 
                     scales={'x':x_sc, 'y':y_sc})
lines = bqplot.Lines(x=state_data_illinois["year"], 
                     y=state_data_illinois["Winter"], 
                     scales={'x':x_sc, 'y':y_sc})
line_figure = bqplot.Figure(marks = [lines], axes = [x_ax, y_ax1])
line_figure
# sc_x = bqplot.LinearScale()
# sc_y = bqplot.LinearScale()

# patch = bqplot.Lines(
#     x=[
#         state_data_illinois["year"],
#         state_data_illinois["year"],
#         state_data_illinois["year"],
#         state_data_illinois["year"]
#     ],
#     y=[
#         state_data_illinois["Spring"],
#         state_data_illinois["Summer"],
#         state_data_illinois["Fall"],
#         state_data_illinois["Spring"],
#     ],
#     fill_colors=["green", "red", "yellow", "blue"],
#     fill="inside",
#     stroke_width=10,
#     close_path=True,
#     scales={"x": sc_x, "y": sc_y},
#     display_legend=True,
# )

# fig = bqplot.Figure(marks=[lines],  axes = [x_ax, y_ax1])
# fig
# Out:
# Figure(axes=[Axis(label='Year', scale=DateScale()), Axis(label='Spring', orientation='vertical', scale=LinearS…

# %% [markdown]
# **Observation: the season data stays the same over years, which is probably generated**\
# Thus it is resonable to focus on the column tempc and temp if we are going to explore how temperature is changing over the years

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ### **Explore temperatures by State per Year**

# %% [markdown]
# **Shooting for something like this:**

# %%
import PIL.Image

# %%
# !wget = https://www.someka.net/wp-content/uploads/2016/05/USA-Geographic-Heat-Map-Generator-Excel-Template-Someka-SS3.png
# Out:
# --2022-12-08 23:12:48--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-12-08 23:12:48--  https://www.someka.net/wp-content/uploads/2016/05/USA-Geographic-Heat-Map-Generator-Excel-Template-Someka-SS3.png
# Resolving www.someka.net (www.someka.net)... 162.159.135.42
# Connecting to www.someka.net (www.someka.net)|162.159.135.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57325 (56K) [image/png]
# Saving to: ‘USA-Geographic-Heat-Map-Generator-Excel-Template-Someka-SS3.png’
#
# USA-Geographic-Heat 100%[===================>]  55.98K  --.-KB/s    in 0.01s
#
# 2022-12-08 23:12:48 (5.09 MB/s) - ‘USA-Geographic-Heat-Map-Generator-Excel-Template-Someka-SS3.png’ saved [57325/57325]
#
# FINISHED --2022-12-08 23:12:48--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 56K in 0.01s (5.09 MB/s)

# %% [markdown]
# ####**explore the difference between states**
# Extract states

# %%
mydata = state_data[0:1375]
mydata
# Out:
#      fips  year       temp      tempc      Fall    Spring    Summer    Winter  \
# 0      01  1895  61.641667  16.467593 -0.195668 -0.105862 -0.325009  0.458526
# 1      01  1896  64.266667  17.925926 -0.195668 -0.105862 -0.325009  0.458526
# 2      01  1897  64.191667  17.884259 -0.195668 -0.105862 -0.325009  0.458526
# 3      01  1898  62.983333  17.212963 -0.195668 -0.105862 -0.325009  0.458526
# 4      01  1899  63.100000  17.277778 -0.195668 -0.105862 -0.325009  0.458526
# ...   ...   ...        ...        ...       ...       ...       ...       ...
# 1370   17  2015  52.875000  11.597222  0.557305  1.153298  0.217481  1.308741
# 1371   17  2016  54.733333  12.629630  0.557305  1.153298  0.217481  1.308741
# 1372   17  2017  54.391667  12.439815  0.557305  1.153298  0.217481  1.308741
# 1373   17  2018  52.475000  11.375000  0.557305  1.153298  0.217481  1.308741
# 1374   17  2019  52.091667  11.162037  0.557305  1.153298  0.217481  1.308741
#
#      max_warming_season    Annual STUSAB STATE_NAME  STATENS
# 0                Winter -0.035048     AL    Alabama  1779775
# 1                Winter -0.035048     AL    Alabama  1779775
# 2                Winter -0.035048     AL    Alabama  1779775
# 3                Winter -0.035048     AL    Alabama  1779775
# 4                Winter -0.035048     AL    Alabama  1779775
# ...                 ...       ...    ...        ...      ...
# 1370             Winter  0.814420     IL   Illinois  1779784
# 1371             Winter  0.814420     IL   Illinois  1779784
# 1372             Winter  0.814420     IL   Illinois  1779784
# 1373             Winter  0.814420     IL   Illinois  1779784
# 1374             Winter  0.814420     IL   Illinois  1779784
#
# [1375 rows x 13 columns]

# %%
mydata_2000 = mydata[ mydata['year']==2000]
# compare_data = mydata.groupby([mydata['year']==2000, 'STATE_NAME'])["temp"].mean()

# compare_data = compare_data.pivot(index='year', 
#                                   columns='STATE_NAME', 
#                                   values='temp')
compare_data = mydata_2000.groupby(['STATE_NAME'])["temp"].mean()
compare_data = compare_data.reset_index()
compare_data
# Out:
#      STATE_NAME       temp
# 0       Alabama  63.566667
# 1       Arizona  61.675000
# 2      Arkansas  60.891667
# 3    California  58.800000
# 4      Colorado  47.000000
# 5   Connecticut  48.533333
# 6      Delaware  54.741667
# 7       Florida  70.575000
# 8       Georgia  63.350000
# 9         Idaho  43.933333
# 10     Illinois  52.200000

# %%
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.LinearScale()

bar = bqplot.Bars(x=compare_data['STATE_NAME'], y=compare_data['temp'], scales={"x": x_sc, "y": y_sc})
ax_x = bqplot.Axis(scale=x_sc)
ax_y = bqplot.Axis(scale=y_sc, tick_format="0.2f", orientation="vertical")

bqplot.Figure(marks=[bar], axes=[ax_x, ax_y], padding_x=0.025, padding_y=0.025)
# Out:
# Figure(axes=[Axis(scale=OrdinalScale()), Axis(orientation='vertical', scale=LinearScale(), tick_format='0.2f')…

# %%
us_map_data = bqplot.topo_load('map_data/USStatesMap.json')

# %%
state_mean_data
# Out:
# STATE_NAME   fips
# Alabama      01      63.195400
# Arizona      04      59.651200
# Arkansas     05      60.543133
# California   06      57.633267
# Colorado     08      44.835667
# Connecticut  09      48.327733
# Delaware     10      54.524667
# Florida      12      70.327667
# Georgia      13      63.525533
# Idaho        16      42.798600
# Illinois     17      51.783733
# Name: temp, dtype: float64

# %%
us_map_data = bqplot.topo_load('map_data/USStatesMap.json')

# Scale
geo_sc = bqplot.AlbersUSA()
clr_sc = bqplot.ColorScale(scheme='Oranges')

# Axis
clr_ax = bqplot.ColorAxis(scale=clr_sc, side='top')

# Mark
# us_map = bqplot.Map(map_data = us_map_data, 
#                     scales={'projection':geo_sc, 'color':clr_sc}, 
#                     color = clr)

# %% [markdown]
# ### TODO: explore heat map by using the data of temperature of different county
